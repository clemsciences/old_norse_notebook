# %% [markdown]
# # Parsing Zoëaga's entries

# %% [markdown]
# ### Configuration
#
# Install the modules.
# ```bash
# $ pip3 install -r requirements.txt
# ```

# %% [markdown]
# Install the **kernel** associated with **python3.6** [https://ipython.readthedocs.io/en/stable/install/kernel_install.html](https://ipython.readthedocs.io/en/stable/install/kernel_install.html)

# %%
import zoegas
help(zoegas)
# Out:
# Help on package zoegas:
#
# NAME
#     zoegas
#
# PACKAGE CONTENTS
#     constants
#     reader
#     tests
#     utils
#
# FILE
#     /home/clementbesnier/.virtualenvs/old_norse_notebook/src/zoegas/zoegas/__init__.py

# %%
from zoegas import reader

# %%
dictionary = reader.Dictionary(reader.dictionary_name)
dictionary.get_entries()

# %%
word = dictionary.find("heimr")
print(word.word)
print(word.description)
# Out:
# heimr
#
#
# (-s, -ar), m.
#
# 1) a place of abode, a region or world (níu man ek heima); spyrja e-n í hvern heim, to ask one freely;
#
# 2) this world (segðu mér ór heimi, ek man ór helju); koma í heiminn, to be born; fara af heiminum, to depart this life; liggja milli heims ok heljar, to lie between life and death;
#
# 3) the earth; kringla heimsins, the globe.

# %% [markdown]
# ##### Letters present in *ZD*:

# %%
dictionary.get_entries()
entries = [entry.word for entry in dictionary.entries if entry is not None]
zd_characters = {c for word in entries if word is not None for c in word if not c.isdigit() and c.islower() and c.isalpha()}

# %%
print(" ".join(sorted(list(zd_characters))))
# Out:
# a b d e f g h i j k l m n o p r s t u v w x y z á æ é í ð ó ö ø ú ý þ œ

# %%
import random
random.seed(30)

# %%
import re

# %%
entries = {entry.word: entry.description for entry in dictionary.entries if entry is not None}

# %%
l = list(entries.keys())

# %%
random.shuffle(l)

# %%
words_to_test = l[:100]

# %%
for word in words_to_test:
    print("--------------")
    print(word)
    entry = dictionary.find(word)
    print(entry.pos)
    print(entries[word])
# Out:
# --------------
# grœ
# []
#
#
#
# --------------
# allr
# ['adjective', 'neuter', 'singular', 'comparative', 'genitive', 'plural', 'genitive', 'plural']
#
#
# (öll, allt), a.
#
# 1) all, entire, whole;
#
# hón á allan arf eptir mik, she has all the heritage after me;
#
# af öllum hug, with all (one’s) heart;
#
# hvítr ~, white all over;
#
# bú allt, the whole estate;
#
# allan daginn, the whole day;
#
# í ~i veröld, in the whole world;
#
# allan hálfan mánuð, for the entire fortnight;
#
# with addition of ‘saman’;
#
# allt saman féit, the whole amount;
#
# um þenna hernað allan saman, all together;
#
# 2) used almost adverbially, all, quite, entirely;
#
# klofnaði hann ~ í sundr, he was all cloven asunder, kváðu Örn allan villast, that he was altogether bewildered;
#
# var Hrappr ~ brottu, quite gone;
#
# ~ annarr maðr, quite another man;
#
# 3) gone, past;
#
# áðr þessi dagr er ~, before this day is past;
#
# var þá óll þeirra vinátta, their friendship was all over;
#
# allt er nú mitt megin, my strength is exhausted, gone;
#
# 4) departed, dead (þá er Geirmundr var ~);
#
# 5) neut. sing. (allt) used. as a subst. in the sense of all, everything;
#
# eigi er enn þeirra allt, they have not yet altogether won the game;
#
# þá var allt (all, everybody) við þá hrætt;
#
# hér er skammætt allt, here everything is transient;
#
# with a compar. all the more (því öllu þungbærri);
#
# with gen., allt missera (= öll misseri), all the year round;
#
# allt annars, all the rest;
#
# at öllu annars, in all other respects;
#
# alls fyrst, first of all;
#
# alls mest, most of all;
#
# in adverbial phrases: at öllu, in all respects, in every way;
#
# í öllu, in everything;
#
# með öllu, wholly, quite;
#
# neita með öllu, to refuse outright;
#
# 6) pl. allir (allar, öll), as adj. or substantively, all (þeir gengu út allir);
#
# ór öllum fjórðungum á landinu, from all the quarters of the land;
#
# allir aðrir, all others, every one else;
#
# flestir allir, nearly all, the greatest part of;
#
# gen. pl. (~a) as an intensive with superlatives, of all things, all the more;
#
# nú þykkir mér þat ~a sýnst, er, all the more likely, as;
#
# ~a helzt, er þeir heyra, particularly now when they hear;
#
# ~a sízt, least of all.
#
#
# --------------
# ístöðulauss
# ['adjective']
#
#
# a. weak, faint-hearted.
#
#
# --------------
# mannæta
# ['feminine noun']
#
#
# f. cannibal.
#
#
# --------------
# drjúglátr
# ['adjective']
#
#
# a. self-important.
#
#
# --------------
# ættliðr
# ['masculine noun']
#
#
# m. a link in a pedigree.
#
#
# --------------
# lágamessa
# ['feminine noun']
#
#
# f. the ‘low chant’ (in the Roman Catholic Mass).
#
#
# --------------
# jafningi
# ['plural', 'masculine noun']
#
#
# (pl. -jar), m. equal, match.
#
#
# --------------
# meginherað
# ['neuter noun']
#
#
# n. main district.
#
#
# --------------
# hestageldir
# ['masculine noun']
#
#
# m. horse gelder.
#
#
# --------------
# sólarsetr
# ['neuter noun']
#
#
# n. sunset.
#
#
# --------------
# brjóstfriðr
# ['masculine noun']
#
#
# m. peace of mind.
#
#
# --------------
# þverskurðr
# ['masculine noun']
#
#
# m. transverse cut.
#
#
# --------------
# eyðiland
# ['neuter noun']
#
#
# n. desert land.
#
#
# --------------
# fjaðrhamr
# ['masculine noun']
#
#
# m. feather-coat.
#
#
# --------------
# teinærr
# ['adjective']
#
#
# a. ten-oared (skip teinært).
#
#
# --------------
# skynugr
# ['adjective']
#
#
# a. sagacious (vitr ok s.).
#
#
# --------------
# torkenna
# ['verb']
#
#
# (-da, -dr), v. to disguise.
#
#
# --------------
# góðfúss
# []
#
#
#
# --------------
# líft
# ['adjective', 'neuter noun']
#
#
# a. n. permitted to live (er-at l. vinum Ingimundar).
#
#
# --------------
# stórflokkar
# ['masculine noun', 'plural']
#
#
# m. pl. large detachments.
#
#
# --------------
# ormsbit
# ['neuter noun']
#
#
# n. snake-bite.
#
#
# --------------
# tilslœgja
# ['feminine noun']
#
#
# f. profit, = slœgr.
#
#
# --------------
# heilsubót
# ['feminine noun']
#
#
# f. improvement of health, recovery.
#
#
# --------------
# lurkr
# ['masculine noun']
#
#
# (-s, -ar), m. cudgel.
#
#
# --------------
# hjartablauðr
# []
#
#
#
# --------------
# ey
# ['adverb', 'genitive', 'dative', 'plural', 'feminine noun']
#
#
# I)
#
# adv.
#
# 1) always, ever, = ei, æ;
#
# 2) not, = ei, eigi;
#
# ey manni þat veit, no man knows.
#
# II)
#
# (gen. eyjar, dat. ey and eyju; pl. eyjar), f. an island.
#
#
# --------------
# hrossbak
# ['neuter noun']
#
#
# n. horseback; á ~i, on horseback.
#
#
# --------------
# biskupsherbergi
# ['neuter noun', 'plural']
#
#
# n. pl. bishop’s apartments.
#
#
# --------------
# aftakamaðr
# ['masculine noun']
#
#
# m. a determined person (~ um e-t).
#
#
# --------------
# mundmál
# ['neuter noun']
#
#
# n. = mundarmál.
#
#
# --------------
# ástalauss
# []
#
#
#
# --------------
# skukkóttr
# ['adjective']
#
#
# a. wrinkled (of clothes).
#
#
# --------------
# nánd
# ['feminine noun']
#
#
# f. neighborhood, nearness, proximity; koma í ~ (or í ~ir) e-u, to come near to.
#
#
# --------------
# hríðdrepa
# ['adjective', 'indeclinable']
#
#
# a. indecl. killed by a snow-storm.
#
#
# --------------
# hálfvirði
# ['neuter noun']
#
#
# n. half worth.
#
#
# --------------
# hefla
# ['verb']
#
#
# (að), v. to furl the sail.
#
#
# --------------
# vöku-
# ['genitive', 'genitive']
#
#
# I)
#
# gen. from vaka.
#
# II)
#
# gen. from vökva.
#
#
# --------------
# brakun
# ['masculine noun']
#
#
# m. intermediary, broker.
#
#
# --------------
# áleitiligr
# []
#
#
#
# --------------
# nefsíðr
# ['adjective']
#
#
# a. long-nosed.
#
#
# --------------
# blótvöllr
# ['masculine noun']
#
#
# m. heathen sacrificial field.
#
#
# --------------
# þjóstr
# ['masculine noun']
#
#
# m. anger, fury, vehemence.
#
#
# --------------
# harðreiðr
# ['adjective']
#
#
# a. hard to ride on.
#
#
# --------------
# laupr
# ['masculine noun']
#
#
# (-s, -ar), m.
#
# 1) basket, box;
#
# 2) the framework of a building.
#
#
# --------------
# nafnkunnigr
# ['adjective']
#
#
# a. renowned.
#
#
# --------------
# nautabrunnr
# ['masculine noun']
#
#
# m. well for watering cattle.
#
#
# --------------
# kennimaðr
# ['masculine noun']
#
#
# m. teacher, cleric, priest.
#
#
# --------------
# feima
# ['feminine noun']
#
#
# f. bashful girl.
#
#
# --------------
# skjávindauga
# ['feminine noun']
#
#
# f. membrane window.
#
#
# --------------
# músarbragð
# ['neuter noun']
#
#
# n. a trick in wrestling.
#
#
# --------------
# máldjarfr
# ['adjective']
#
#
# a., free-spoken.
#
#
# --------------
# útrúliga
# ['adverb']
#
#
# adv.
#
# 1) unfaithfully;
#
# 2) incredibly.
#
#
# --------------
# lasta
# ['verb']
#
#
# I) (að), v. to blame, speak ill of.
#
# II) from löstr, fault.
#
#
# --------------
# norðastr
# []
#
#
#
# --------------
# dreyrrauðr
# ['adjective']
#
#
# a. red as blood;
#
# e-n setr dreyrrauðan, one turns scarlet (Guðrúnu setti dreyrrauða).
#
#
# --------------
# ártal
# ['neuter noun']
#
#
# n. reckoning by years.
#
#
# --------------
# þot
# ['neuter noun']
#
#
# n. rush; in phrase, sitja (standa) í þot við e-n, to sit (stand) ready to make (? or meet) an attack.
#
#
# --------------
# legkaup
# ['neuter noun']
#
#
# n. burial-fee.
#
#
# --------------
# úrífligr
# ['adjective']
#
#
# a.
#
# 1) bad, unfavourable;
#
# 2) scanty.
#
#
# --------------
# flokksforingi
# []
#
#
#
# --------------
# meinlætasamr
# ['adjective']
#
#
# a. = meinlátsamr.
#
#
# --------------
# úvinfengi
# ['neuter noun']
#
#
# n. unfriendliness, bad feeling.
#
#
# --------------
# glam
# []
#
#
#
# --------------
# mótfjalir
# ['feminine noun', 'plural']
#
#
# f. pl. the platform on which meetings were held.
#
#
# --------------
# vistafæð
# ['feminine noun']
#
#
# f. lack of provisions.
#
#
# --------------
# brottfýsi
# ['feminine noun']
#
#
# f. eagerness to get away.
#
#
# --------------
# lofsorð
# ['neuter noun']
#
#
# n. praise.
#
#
# --------------
# þingheyjandi
# ['masculine noun']
#
#
# m. a ‘þing-performer’, any person who visits a þing, on a summons to perform any public duty.
#
#
# --------------
# jaðraskegg
# ['neuter noun']
#
#
# n. whiskers.
#
#
# --------------
# innlenzkr
# ['adjective']
#
#
# a. indigenous.
#
#
# --------------
# buðkr
# ['masculine noun']
#
#
# m. small box (originally a box to keep herbs and balsams in).
#
#
# --------------
# ofrefli
# ['neuter noun']
#
#
# n.
#
# 1) overwhelming force (þessi maðr brýzt í móti miklu ~);
#
# 2) Oddr kvað sér þat eigi ~, O. said it was not beyond his strength;
#
# 3) excess, immensity (~ frosts ok kulda).
#
#
# --------------
# reynilundr
# ['masculine noun']
#
#
# m. rowan-grove.
#
#
# --------------
# dygðugr
# ['adjective']
#
#
# a.
#
# 1) faithful, trusty (~ maðr);
#
# 2) efficacious (dygðugt oleum).
#
#
# --------------
# sœmdarvœnligr
# ['adjective']
#
#
# a. promising honour.
#
#
# --------------
# silkihjúpr
# ['masculine noun']
#
#
# m. silken jacket.
#
#
# --------------
# hagskeytr
# []
#
#
#
# --------------
# prúðleikr
# ['masculine noun']
#
#
# m. show, ornament.
#
#
# --------------
# víðleikr
# ['masculine noun']
#
#
# m. width, extent.
#
#
# --------------
# alkunnigr
# []
#
#
#
# --------------
# sængarkona
# []
#
#
# = sængrkona.
#
#
# --------------
# stryk
# ['neuter noun']
#
#
# n. stroke (merkja ena löngu stafi með ~i).
#
#
# --------------
# kólfr
# ['masculine noun']
#
#
# (-s, -ar), m.
#
# 1) clapper, tongue of a bell;
#
# 2) a kind of bolt; svá skjótt (snart) sem kólfi skjóti (skyti), swift as an arrow.
#
#
# --------------
# leiga
# ['verb', 'feminine noun']
#
#
# I)
#
# (-ða, -ðr), v. to hire, rent; ~ e-t at e-m, to hire from a person.
#
# II)
#
# f.
#
# 1) hire, rent, opp. to innstœða (capital); byggja fé á leigu, to let money out at interest; leggja leigu eptir höfn, to pay a harbour duty;
#
# 2) wages, pay (kallast hann engrar leigu makligr).
#
#
# --------------
# brjóstkirkja
# ['feminine noun']
#
#
# f. the heart.
#
#
# --------------
# lokhvíluþil
# ['neuter noun']
#
#
# n. wainscot or panelling of a bed-closet.
#
#
# --------------
# útæpiliga
# ['adverb']
#
#
# adv.
#
# 1) unsparingly;
#
# 2) fully; kenna ~, to feel it unmistakably, smart sorely.
#
#
# --------------
# motra
# ['feminine noun']
#
#
# f. a woman wearing a motr.
#
#
# --------------
# skyti
# ['masculine noun']
#
#
# I) m. marksman, shooter, harpooner (~ allra manna beztr).
#
# II) from skjóta.
#
#
# --------------
# steinkirkja
# ['feminine noun']
#
#
# f. stone church.
#
#
# --------------
# skjaðak
# ['neuter noun']
#
#
# n.
#
# 1) a kind of weed, darnel;
#
# 2) an ill-flavoured or poisonous element (s. í mungáti).
#
#
# --------------
# iðna
# ['verb']
#
#
# (að), v.
#
# 1) to do, perform, = iðja;
#
# 2) to work at (a thing).
#
#
# --------------
# heimilisfastr
# ['adjective']
#
#
# a. having a fixed homestead.
#
#
# --------------
# mergr
# ['genitive', 'masculine noun']
#
#
# (gen. -jar), m. marrow.
#
#
# --------------
# smíðarefni
# ['neuter noun']
#
#
# n. materials for some work.
#
#
# --------------
# happaverk
# ['neuter noun']
#
#
# n. happy deed.
#
#
# --------------
# smásmugligr
# ['adjective']
#
#
# a. minute.
#
#
# --------------
# matarbur
# []
#
#
#
# --------------
# dyrr
# ['genitive', 'feminine noun', 'plural']
#
#
# (gen. dura), f. pl. door opening, doorway (Oddr hljóp út or durunum).

# %%
print(words_to_test[0])
[entry.word for entry in dictionary.find_beginning_with(words_to_test[0])]
# Out:
# grœ
# ['grœfi',
#  'grœ',
#  'grœða',
#  'grœðari',
#  'grœðiligr',
#  'grœðing',
#  'grœfr',
#  'grœgr',
#  'grœnast',
#  'grœnfainn',
#  'grœnleikr',
#  'grœnlenzkr',
#  'grœnn',
#  'grœntó',
#  'grœntyrfa',
#  'grœta',
#  'grœti',
#  'grœtiligr',
#  'grœtir',
#  'grœfi',
#  'grœ',
#  'grœða',
#  'grœðari',
#  'grœðiligr',
#  'grœðing',
#  'grœfr',
#  'grœgr',
#  'grœnast',
#  'grœnfainn',
#  'grœnleikr',
#  'grœnlenzkr',
#  'grœnn',
#  'grœntó',
#  'grœntyrfa',
#  'grœta',
#  'grœti',
#  'grœtiligr',
#  'grœtir']

# %% [markdown]
# --------------------------------

# %%
words_to_test[1], entries[words_to_test[1]]
# Out:
# ('allr',
#  '\n\n(öll, allt), a.\n\n1) all, entire, whole;\n\nhón á allan arf eptir mik, she has all the heritage after me;\n\naf öllum hug, with all (one’s) heart;\n\nhvítr ~, white all over;\n\nbú allt, the whole estate;\n\nallan daginn, the whole day;\n\ní ~i veröld, in the whole world;\n\nallan hálfan mánuð, for the entire fortnight;\n\nwith addition of ‘saman’;\n\nallt saman féit, the whole amount;\n\num þenna hernað allan saman, all together;\n\n2) used almost adverbially, all, quite, entirely;\n\nklofnaði hann ~ í sundr, he was all cloven asunder, kváðu Örn allan villast, that he was altogether bewildered;\n\nvar Hrappr ~ brottu, quite gone;\n\n~ annarr maðr, quite another man;\n\n3) gone, past;\n\náðr þessi dagr er ~, before this day is past;\n\nvar þá óll þeirra vinátta, their friendship was all over;\n\nallt er nú mitt megin, my strength is exhausted, gone;\n\n4) departed, dead (þá er Geirmundr var ~);\n\n5) neut. sing. (allt) used. as a subst. in the sense of all, everything;\n\neigi er enn þeirra allt, they have not yet altogether won the game;\n\nþá var allt (all, everybody) við þá hrætt;\n\nhér er skammætt allt, here everything is transient;\n\nwith a compar. all the more (því öllu þungbærri);\n\nwith gen., allt missera (= öll misseri), all the year round;\n\nallt annars, all the rest;\n\nat öllu annars, in all other respects;\n\nalls fyrst, first of all;\n\nalls mest, most of all;\n\nin adverbial phrases: at öllu, in all respects, in every way;\n\ní öllu, in everything;\n\nmeð öllu, wholly, quite;\n\nneita með öllu, to refuse outright;\n\n6) pl. allir (allar, öll), as adj. or substantively, all (þeir gengu út allir);\n\nór öllum fjórðungum á landinu, from all the quarters of the land;\n\nallir aðrir, all others, every one else;\n\nflestir allir, nearly all, the greatest part of;\n\ngen. pl. (~a) as an intensive with superlatives, of all things, all the more;\n\nnú þykkir mér þat ~a sýnst, er, all the more likely, as;\n\n~a helzt, er þeir heyra, particularly now when they hear;\n\n~a sízt, least of all.\n\n')

# %%
lines = [line for line in entries[words_to_test[1]].split("\n") if line]
lines
# Out:
# ['(öll, allt), a.',
#  '1) all, entire, whole;',
#  'hón á allan arf eptir mik, she has all the heritage after me;',
#  'af öllum hug, with all (one’s) heart;',
#  'hvítr ~, white all over;',
#  'bú allt, the whole estate;',
#  'allan daginn, the whole day;',
#  'í ~i veröld, in the whole world;',
#  'allan hálfan mánuð, for the entire fortnight;',
#  'with addition of ‘saman’;',
#  'allt saman féit, the whole amount;',
#  'um þenna hernað allan saman, all together;',
#  '2) used almost adverbially, all, quite, entirely;',
#  'klofnaði hann ~ í sundr, he was all cloven asunder, kváðu Örn allan villast, that he was altogether bewildered;',
#  'var Hrappr ~ brottu, quite gone;',
#  '~ annarr maðr, quite another man;',
#  '3) gone, past;',
#  'áðr þessi dagr er ~, before this day is past;',
#  'var þá óll þeirra vinátta, their friendship was all over;',
#  'allt er nú mitt megin, my strength is exhausted, gone;',
#  '4) departed, dead (þá er Geirmundr var ~);',
#  '5) neut. sing. (allt) used. as a subst. in the sense of all, everything;',
#  'eigi er enn þeirra allt, they have not yet altogether won the game;',
#  'þá var allt (all, everybody) við þá hrætt;',
#  'hér er skammætt allt, here everything is transient;',
#  'with a compar. all the more (því öllu þungbærri);',
#  'with gen., allt missera (= öll misseri), all the year round;',
#  'allt annars, all the rest;',
#  'at öllu annars, in all other respects;',
#  'alls fyrst, first of all;',
#  'alls mest, most of all;',
#  'in adverbial phrases: at öllu, in all respects, in every way;',
#  'í öllu, in everything;',
#  'með öllu, wholly, quite;',
#  'neita með öllu, to refuse outright;',
#  '6) pl. allir (allar, öll), as adj. or substantively, all (þeir gengu út allir);',
#  'ór öllum fjórðungum á landinu, from all the quarters of the land;',
#  'allir aðrir, all others, every one else;',
#  'flestir allir, nearly all, the greatest part of;',
#  'gen. pl. (~a) as an intensive with superlatives, of all things, all the more;',
#  'nú þykkir mér þat ~a sýnst, er, all the more likely, as;',
#  '~a helzt, er þeir heyra, particularly now when they hear;',
#  '~a sízt, least of all.']

# %%
re.lines[0]

# %% [markdown]
# --------------------------------

# %%
len(dictionary.entries)
# Out:
# 59902

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# --------------------------------

# %% [markdown]
# The task is to get part of speech of each entry.

# %% [markdown]
# By Clément Besnier, email address: clemsciences@aol.com, web site: https://clementbesnier.fr/, twitter: clemsciences
